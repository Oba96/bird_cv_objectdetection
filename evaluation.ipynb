# %% [markdown]
# Evaluation

# %%
PATH_TO_MODEL = "/home/msc1/Desktop/tagging/public/birdtask/train/faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
# %cd /home/msc1/Desktop/tagging/public/birdtask/scripts
# Out:
# /home/msc1/Desktop/tagging/public/birdtask/scripts

# %%
# !CUDA_VISIBLE_DEVICES="" python model_main_tf2.py --pipeline_config_path={PATH_TO_MODEL}/pipeline.config --model_dir={PATH_TO_MODEL} --checkpoint_dir={PATH_TO_MODEL} --alsologtostderr
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0104 10:35:05.050934 140252372686656 model_lib_v2.py:919] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0104 10:35:05.051019 140252372686656 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0104 10:35:05.051061 140252372686656 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0104 10:35:05.051099 140252372686656 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %% [markdown]
# Summary: This is the evaluation part, this will run with the training script to achieve a good results in terms of loss and also in this case to retrieve the IoU @0.5 and @0.75. This scrpit will run on cpu and the training on the gpu.
