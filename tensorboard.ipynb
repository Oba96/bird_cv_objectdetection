# %%
PATH_TO_MODEL = "/home/msc1/Desktop/tagging/public/birdtask/train/faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
# !tensorboard --logdir={PATH_TO_MODEL}/
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.2.1 at http://localhost:6008/ (Press CTRL+C to quit)

# %% [markdown]
# This is part regards the tensorBoard site, this will show the graphs of the total loss of the model and also some metrics of AP(for the object detection we will look at @0.50 and @0.75)

# %%
from IPython.display import Image

# %% [markdown]
# Total loss

# %%
Image("/home/msc1/Desktop/tagging/public/birdtask/total_loss.png")

# %% [markdown]
# We can in this graph the total loss starts to overfit around 30 epochs, so the checkpoint for the inference will be set 24k steps(epochs) which seems the best point for model

# %% [markdown]
# MAP @0.5

# %%
Image("/home/msc1/Desktop/tagging/public/birdtask/map0.5.png")

# %% [markdown]
# MAP @0.75

# %%
Image("/home/msc1/Desktop/tagging/public/birdtask/map0.75.png")

# %% [markdown]
# How we can see in these graphs the epochs was set to 30000, because the total loss is quit, probarly performing for more epochs the model can  overfit; with this settings and epoch we achieved a good results in both metrics
