# %% [markdown]
# Training

# %%
PATH_TO_MODEL = "/home/msc1/Desktop/tagging/public/birdtask/train/faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %% [markdown]
# This is dir of the pretrained model which will bw used to train the actual model. For this type of dataset(bird), faster rcnn 101 will be better because it is very efficient in detecting small objects.

# %%
# !gedit {PATH_TO_MODEL}/pipeline.config
# Out:
# ** (gedit:545885): WARNING **: 14:51:46.169: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ** (gedit:545885): WARNING **: 14:51:46.169: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ** (gedit:545885): WARNING **: 14:51:46.170: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ** (gedit:545885): WARNING **: 14:51:46.170: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ** (gedit:545885): WARNING **: 14:51:46.170: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ** (gedit:545885): WARNING **: 14:51:46.170: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ** (gedit:545885): WARNING **: 14:51:46.170: Could not load theme icon text-x-generic: Icon 'text-x-generic' not present in theme Adwaita
#
# ...

# %% [markdown]
# The pipeline contains the configuration hyperparameter tune settings.

# %%
# %cd /home/msc1/Desktop/tagging/public/birdtask/scripts
# Out:
# /home/msc1/Desktop/tagging/public/birdtask/scripts

# %%
# !python model_main_tf2.py --model_dir={PATH_TO_MODEL} --pipeline_config_path={PATH_TO_MODEL}/pipeline.config --num_train_steps=30000 --alsologtostderr
# Out:
# 2021-01-04 10:35:46.609598: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 10:35:46.623603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-04 10:35:46.623891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-01-04 10:35:46.623997: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-04 10:35:46.624872: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path {PATH_TO_MODEL}/pipeline.config --trained_checkpoint_dir {PATH_TO_MODEL}/ --output_directory {PATH_TO_MODEL}/saved_model/
# Out:
# 2021-01-04 15:01:33.617680: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-01-04 15:01:33.622242: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-04 15:01:33.622679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-01-04 15:01:33.622887: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-04 15:01:33.624445: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %% [markdown]
# Summary: This is second process, which is the training, this part is very important it is needed to run in simultaneous with the evaluation in order to archive a good results in terms of loss. The steps are the epochs which it is set 30000. After the training and evaluation this will exported into a inference graph, which will be needed for predicting new images of birds. Important to address that the training will be train on the gpu and the evaluation will be on cpu.
